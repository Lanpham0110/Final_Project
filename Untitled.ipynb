# %%
import os
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np

# %%
#reading clean files and combining them to one.
happy_2017 = pd.read_csv('CleanData/2017_cleaned.csv')
happy_2017.head(5)
# Out:
#    Unnamed: 0      Country  Overall rank  Score  GDP per capita    Family  \
# 0           0       Norway             1  7.537        1.616463  1.533524
# 1           1      Denmark             2  7.522        1.482383  1.551122
# 2           2      Iceland             3  7.504        1.480633  1.610574
# 3           3  Switzerland             4  7.494        1.564980  1.516912
# 4           4      Finland             5  7.469        1.443572  1.540247
#
#    Healthy life expectancy   Freedom  Generosity  Perceptions of corruption
# 0                 0.796667  0.635423    0.362012                   0.315964
# 1                 0.792566  0.626007    0.355280                   0.400770
# 2                 0.833552  0.627163    0.475540                   0.153527
# 3                 0.858131  0.620071    0.290549                   0.367007
# 4                 0.809158  0.617951    0.245483                   0.382612

# %%
happy_2017['Year'] = 2017

# %%
happy_2018 = pd.read_csv('CleanData/2018_cleaned.csv')
happy_2018.head(5)
# Out:
#    Unnamed: 0  Overall rank      Country  Score  GDP per capita  \
# 0           0             1      Finland  7.632           1.305
# 1           1             2       Norway  7.594           1.456
# 2           2             3      Denmark  7.555           1.351
# 3           3             4      Iceland  7.495           1.343
# 4           4             5  Switzerland  7.487           1.420
#
#    Social support  Healthy life expectancy  Freedom  Generosity  \
# 0           1.592                    0.874    0.681       0.202
# 1           1.582                    0.861    0.686       0.286
# 2           1.590                    0.868    0.683       0.284
# 3           1.644                    0.914    0.677       0.353
# 4           1.549                    0.927    0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# 2                      0.408
# 3                      0.138
# 4                      0.357

# %%
happy_2018['Year'] = 2018

# %%
happy_2019 = pd.read_csv('CleanData/2019_cleaned.csv')
happy_2019.head(5)
# Out:
#    Unnamed: 0  Overall rank      Country  Score  GDP per capita  \
# 0           0             1      Finland  7.769           1.340
# 1           1             2      Denmark  7.600           1.383
# 2           2             3       Norway  7.554           1.488
# 3           3             4      Iceland  7.494           1.380
# 4           4             5  Netherlands  7.488           1.396
#
#    Social support  Healthy life expectancy  Freedom  Generosity  \
# 0           1.587                    0.986    0.596       0.153
# 1           1.573                    0.996    0.592       0.252
# 2           1.582                    1.028    0.603       0.271
# 3           1.624                    1.026    0.591       0.354
# 4           1.522                    0.999    0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %%
happy_2019['Year'] = 2019

# %%
happiness_all = happy_2017.append(happy_2018, ignore_index=True).append(happy_2019, ignore_index=True)\
.drop(columns=['Unnamed: 0', 'Social support']).dropna().set_index('Year')
happiness_all.head(20)
# Out:
#              Country  Overall rank  Score  GDP per capita    Family  \
# Year
# 2017          Norway             1  7.537        1.616463  1.533524
# 2017         Denmark             2  7.522        1.482383  1.551122
# 2017         Iceland             3  7.504        1.480633  1.610574
# 2017     Switzerland             4  7.494        1.564980  1.516912
# 2017         Finland             5  7.469        1.443572  1.540247
# 2017     Netherlands             6  7.377        1.503945  1.428939
# 2017          Canada             7  7.316        1.479204  1.481349
# 2017     New Zealand             8  7.314        1.405706  1.548195
# 2017          Sweden             9  7.284        1.494387  1.478162
# 2017       Australia            10  7.284        1.484415  1.510042
# 2017          Israel            11  7.213        1.375382  1.376290
# 2017      Costa Rica            12  7.079        1.109706  1.416404
# 2017         Austria            13  7.006        1.487097  1.459945
# ...

# %%
happiness_all.to_csv('Onefile.csv')

# %%
happiness_all.to_csv(r'C:\users\sadik\Desktop\DataViz\Homework\Final_Project\Onefile.csv', index=False)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
model = LinearRegression()

# %%
X = happiness_all[['GDP per capita', 'Healthy life expectancy', 'Freedom', 'Generosity','Perceptions of corruption']]
y = happiness_all.Score

# %%
#plt.scatter(X,y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
# Fitting our model with all of our features in X
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train, y_train)
# Out:
# 0.8074658900071973

# %%
score = model.score(X,y)
print(f"R2 Score: {score}")
# Out:
# R2 Score: 0.7649447700725251

# %%
model.score(X_test, y_test)
# Out:
# 0.6348968866274678

# %%
model.coef_
# Out:
# array([ 1.28823051,  1.36914396,  2.70916131,  0.33252642, -0.30217373])

# %%
model.intercept_
# Out:
# 2.206212331571331

# %%
predictions = model.predict(X)
# Plot Residuals
plt.scatter(predictions, predictions - y)
plt.hlines(y=0, xmin=predictions.min(), xmax=predictions.max())
plt.show()

# %% [markdown]
# # Predict higher GDP higher happiness

# %%
happiness_all[happiness_all['GDP per capita'] == happiness_all['GDP per capita'].max()]
# Out:
#      Country  Overall rank  Score  GDP per capita    Family  \
# Year
# 2017   Qatar            35  6.375        1.870766  1.274297
#
#       Healthy life expectancy   Freedom  Generosity  Perceptions of corruption
# Year
# 2017                 0.710098  0.604131    0.330474                   0.439299

# %%
X_test[9:10]
# Out:
#       GDP per capita  Healthy life expectancy   Freedom  Generosity  \
# Year
# 2017         0.47618                 0.169366  0.306614    0.183354
#
#       Perceptions of corruption
# Year
# 2017                    0.10497

# %%
y_test[9:10]
# Out:
# Year
# 2017    4.19
# Name: Score, dtype: float64

# %%
model.predict(X_test[9:10])
# Out:
# array([3.91144552])

# %%
model.predict (X)
# Out:
# array([7.12570561, 6.89399081, 7.06568456, 7.06275858, 6.81386197,
#        6.91053773, 6.96796145, 6.8495285 , 6.9414258 , 6.9715727 ,
#        6.30980961, 6.28843255, 6.81484535, 6.71794958, 6.89802297,
#        6.76901054, 6.67534255, 7.22146937, 6.62641382, 6.0469021 ,
#        6.96648488, 5.68243653, 6.32992963, 6.04296668, 5.7821062 ,
#        7.15059585, 6.80195187, 6.33350706, 5.57955687, 6.3010718 ,
#        6.47069817, 6.29788159, 6.18602795, 6.35600129, 7.20225116,
#        5.72913918, 6.17091535, 6.1823996 , 6.53083064, 5.72896471,
#        6.451743  , 5.92531179, 5.32352037, 5.6750111 , 5.36467631,
#        6.27247889, 5.7486697 , 5.91521127, 5.62689535, 5.52618966,
#        6.64263627, 5.39518665, 5.06943519, 5.61562064, 5.99277366,
#        4.67077752, 5.99412011, 5.49917872, 5.40015158, 5.90702361,
#        6.40245298, 6.63500312, 5.64969354, 6.05009413, 6.1493018 ,
#        6.13515003, 5.37388806, 5.62210551, 5.42300314, 5.53044022,
# ...

# %%
happiness_all['model output predicted happiness']=model.predict (X)

# %%
happiness_all.head()
# Out:
#           Country  Overall rank  Score  GDP per capita    Family  \
# Year
# 2017       Norway             1  7.537        1.616463  1.533524
# 2017      Denmark             2  7.522        1.482383  1.551122
# 2017      Iceland             3  7.504        1.480633  1.610574
# 2017  Switzerland             4  7.494        1.564980  1.516912
# 2017      Finland             5  7.469        1.443572  1.540247
#
#       Healthy life expectancy   Freedom  Generosity  \
# Year
# 2017                 0.796667  0.635423    0.362012
# 2017                 0.792566  0.626007    0.355280
# 2017                 0.833552  0.627163    0.475540
# 2017                 0.858131  0.620071    0.290549
# 2017                 0.809158  0.617951    0.245483
#
#       Perceptions of corruption  model output predicted happiness
# Year
# 2017                   0.315964                          7.125706
# 2017                   0.400770                          6.893991
# ...

# %%
happiness_all.to_csv('Prediction happiness.csv')
